# %% [markdown]
# <a href="https://colab.research.google.com/github/masterAristocats/Proc-Sin-Trabalho-Extra/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Principais figuras

# %%
# !git clone https://github.com/masterAristocats/Proc-Sin-Trabalho-Extra.git

# %cd Proc-Sin-Trabalho-Extra
# Out:
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 213 (delta 15), reused 2 (delta 2), pack-reused 162 (from 1)
# Receiving objects: 100% (213/213), 11.66 MiB | 19.66 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Proc-Sin-Trabalho-Extra

# %%
print("="*60)
print("GERAÇÃO DAS GEOMETRIAS")
print("="*60)

# %run examples/generate_ula.ipynb
# %run examples/generate_uca.ipynb
# %run examples/generate_upa.ipynb
# %run examples/generate_ucya.ipynb
# Out:
# ...
# GERAÇÃO DAS GEOMETRIAS
# ...
# Mounted at /content/drive
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 213 (delta 15), reused 2 (delta 2), pack-reused 162 (from 1)
# Receiving objects: 100% (213/213), 11.66 MiB | 20.03 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra
# beamformer.py	generate_uca.py   generate_ula.py  steering_vector.py
# beampattern.py	generate_ucya.py  generate_upa.py
# [[0.  0.  0. ]
#  [0.5 0.  0. ]
#  [1.  0.  0. ]
#  [1.5 0.  0. ]
#  [2.  0.  0. ]
#  [2.5 0.  0. ]
#  [3.  0.  0. ]
#  [3.5 0.  0. ]]
# [0.5 0.5 0.5 0.5 0.5 0.5 0.5]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# ...

# %%
print("="*60)
print("STEERING VECTOR")
print("="*60)

# %run examples/steering_vector.ipynb
# Out:
# ...
# STEERING VECTOR
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 213 (delta 15), reused 2 (delta 2), pack-reused 162 (from 1)
# Receiving objects: 100% (213/213), 11.66 MiB | 25.08 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra
# beamformer.py	generate_uca.py   generate_ula.py  steering_vector.py
# beampattern.py	generate_ucya.py  generate_upa.py
# [ 1.+0.00000000e+00j -1.-1.22464680e-16j  1.+2.44929360e-16j
#  -1.-3.67394040e-16j  1.+4.89858720e-16j -1.-6.12323400e-16j
#   1.+7.34788079e-16j -1.-8.57252759e-16j  1.+9.79717439e-16j]

# %%
print("="*60)
print("BEAMPATTERN")
print("="*60)

# %run examples/beampattern.ipynb
# Out:
# ...
# BEAMPATTERN
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 213 (delta 15), reused 2 (delta 2), pack-reused 162 (from 1)
# Receiving objects: 100% (213/213), 11.66 MiB | 25.08 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra
# beamformer.py	generate_uca.py   generate_ula.py  steering_vector.py
# beampattern.py	generate_ucya.py  generate_upa.py

# %%
print("="*60)
print("BEAMFORMER")
print("="*60)

# %run examples/beamformer.ipynb
# Out:
# ...
# BEAMFORMER
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 213 (delta 15), reused 2 (delta 2), pack-reused 162 (from 1)
# Receiving objects: 100% (213/213), 11.66 MiB | 24.97 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra
# beamformer.py	generate_uca.py   generate_ula.py  steering_vector.py
# beampattern.py	generate_ucya.py  generate_upa.py
# 6.123233995736767e-17j

# %%
print("="*60)
print("TRANSMISSÃO DIRECIONAL")
print("="*60)

# %run data/directional_transmission.ipynb
# Out:
# ...
# TRANSMISSÃO DIRECIONAL
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 213 (delta 15), reused 2 (delta 2), pack-reused 162 (from 1)
# Receiving objects: 100% (213/213), 11.66 MiB | 20.33 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra
# beamformer.py	generate_uca.py   generate_ula.py  steering_vector.py
# beampattern.py	generate_ucya.py  generate_upa.py
# Potência transmitida : 0.6250
# Potência recebida    : 0.6250
# Ganho do enlace      : 1.0000
# ...

# %%
print("="*60)
print("MÚLTIPLAS FONTES (EXTRA)")
print("="*60)

# %run data/multiple_sources.ipynb
# Out:
# ...
# MÚLTIPLAS FONTES (EXTRA)
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'Proc-Sin-Trabalho-Extra'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 213 (delta 15), reused 2 (delta 2), pack-reused 162 (from 1)
# Receiving objects: 100% (213/213), 11.66 MiB | 24.61 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra/Proc-Sin-Trabalho-Extra
# beamformer.py	generate_uca.py   generate_ula.py  steering_vector.py
# beampattern.py	generate_ucya.py  generate_upa.py

# %%
print("="*60)
print("Todos os experimentos foram executados.")
print("As figuras foram geradas automaticamente.")
print("="*60)
# Out:
# ...
# Todos os experimentos foram executados com sucesso.
# As figuras foram geradas automaticamente.
# ...
